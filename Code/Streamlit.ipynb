# %%
import mlflow
import pandas as pd

# %%
experiment_name = 'Kobe_Bryant_Shot_Experiment'
experiment = mlflow.get_experiment_by_name(experiment_name)
if experiment is None:
    experiment_id = mlflow.create_experiment(experiment_name)
    experiment = mlflow.get_experiment(experiment_id)
experiment_id = experiment.experiment_id

# %%
df_ml = mlflow.search_runs([experiment_id], order_by=["metrics.m DESC"])
df_ml
# Out:
#                                run_id experiment_id    status  \
# 0    0e78cc59cdcc46ffa2cf7d325e94e071             1  FINISHED
# 1    fe94ae7f47824b6487aad17d1a7e7bd7             1  FINISHED
# 2    f48d0ab0640b4e63a53603561c546202             1  FINISHED
# 3    f580b9e531d8488392484e6e130262b6             1  FINISHED
# 4    266abda895364ba3b43cfa6c91a7b71b             1  FINISHED
# ..                                ...           ...       ...
# 231  8d679fb1ea6342dbafea6b37fc04c299             1   RUNNING
# 232  b150433b0eef4aada8cdf83652e992a8             1  FINISHED
# 233  458ec50cfc234ad9abdab7f4bcf2595e             1  FINISHED
# 234  b21ed420ec5444ce9aff9a04ece9ac3a             1   RUNNING
# 235  38daa8008f644b2991685f883e5367d0             1  FINISHED
#
#                                           artifact_uri  \
# 0    ./mlruns/1/0e78cc59cdcc46ffa2cf7d325e94e071/ar...
# 1    ./mlruns/1/fe94ae7f47824b6487aad17d1a7e7bd7/ar...
# 2    ./mlruns/1/f48d0ab0640b4e63a53603561c546202/ar...
# 3    ./mlruns/1/f580b9e531d8488392484e6e130262b6/ar...
# 4    ./mlruns/1/266abda895364ba3b43cfa6c91a7b71b/ar...
# ..                                                 ...
# 231  ./mlruns/1/8d679fb1ea6342dbafea6b37fc04c299/ar...
# 232  ./mlruns/1/b150433b0eef4aada8cdf83652e992a8/ar...
# 233  ./mlruns/1/458ec50cfc234ad9abdab7f4bcf2595e/ar...
# 234  ./mlruns/1/b21ed420ec5444ce9aff9a04ece9ac3a/ar...
# 235  ./mlruns/1/38daa8008f644b2991685f883e5367d0/ar...
#
#                           start_time                         end_time  \
# 0   2022-04-17 22:23:23.094000+00:00 2022-04-17 22:23:25.335000+00:00
# 1   2022-04-17 22:21:35.240000+00:00 2022-04-17 22:21:37.950000+00:00
# 2   2022-04-17 21:44:08.578000+00:00 2022-04-17 21:44:12.444000+00:00
# 3   2022-04-17 21:43:15.710000+00:00 2022-04-17 21:43:19.609000+00:00
# 4   2022-04-17 21:40:10.859000+00:00 2022-04-17 21:40:14.749000+00:00
# ..                               ...                              ...
# 231 2022-04-17 17:56:50.176000+00:00                              NaT
# 232 2022-04-17 17:39:22.708000+00:00 2022-04-17 17:41:06.737000+00:00
# 233 2022-04-17 17:39:15.695000+00:00 2022-04-17 17:41:06.756000+00:00
# 234 2022-04-17 17:39:14.834000+00:00                              NaT
# 235 2022-04-17 16:31:35.025000+00:00 2022-04-17 16:31:35.378000+00:00
#
#      metrics.MCC  metrics.Recall  metrics.Accuracy  metrics.AUC  ...  \
# 0       0.182147        0.402727          0.595514     0.584619  ...
# 1       0.182147        0.402727          0.595514     0.584619  ...
# 2       0.170774        0.370224          0.590881     0.577473  ...
# 3       0.170774        0.370224          0.590881     0.577473  ...
# 4       0.170774        0.370224          0.590881     0.577473  ...
# ..           ...             ...               ...          ...  ...
# 231          NaN             NaN               NaN          NaN  ...
# 232     0.156600        0.479000          0.581700     0.593700  ...
# 233          NaN             NaN               NaN          NaN  ...
# 234          NaN             NaN               NaN          NaN  ...
# 235          NaN             NaN               NaN          NaN  ...
#
#           tags.mlflow.runName  \
# 0           RevalidaçãoModelo
# 1           RevalidaçãoModelo
# 2              RegistroModelo
# 3              RegistroModelo
# 4              RegistroModelo
# ..                        ...
# 231               Treinamento
# 232       Logistic Regression
# 233  Session Initialized f7db
# 234               Treinamento
# 235           PreparacaoDados
#
#                          tags.mlflow.log-model.history  tags.Run Time  \
# 0                                                 None           None
# 1                                                 None           None
# 2    [{"run_id": "f48d0ab0640b4e63a53603561c546202"...           None
# 3    [{"run_id": "f580b9e531d8488392484e6e130262b6"...           None
# 4    [{"run_id": "266abda895364ba3b43cfa6c91a7b71b"...           None
# ..                                                 ...            ...
# 231                                               None           None
# 232  [{"run_id": "b150433b0eef4aada8cdf83652e992a8"...           6.32
# 233                                               None           0.81
# 234                                               None           None
# 235                                               None           None
#
#      tags.USI  tags.URI                       tags.Run ID   tags.Source  \
# 0        None      None                              None          None
# 1        None      None                              None          None
# 2        None      None                              None          None
# 3        None      None                              None          None
# 4        None      None                              None          None
# ..        ...       ...                               ...           ...
# 231      None      None                              None          None
# 232      f7db  2e5ce4e5  b150433b0eef4aada8cdf83652e992a8  create_model
# 233      f7db  33fd6d41  458ec50cfc234ad9abdab7f4bcf2595e         setup
# 234      None      None                              None          None
# 235      None      None                              None          None
#
#      tags.mlflow.autologging  tags.estimator_name  tags.estimator_class
# 0                       None                 None                  None
# 1                       None                 None                  None
# 2                       None                 None                  None
# 3                       None                 None                  None
# 4                       None                 None                  None
# ..                       ...                  ...                   ...
# 231                     None                 None                  None
# 232                     None                 None                  None
# 233                     None                 None                  None
# 234                     None                 None                  None
# 235                     None                 None                  None
#
# [236 rows x 308 columns]

# %%
df_ml_fh = df_ml[df_ml['status'] == 'FINISHED'].copy()
df_ml_fh_rg = df_ml_fh[df_ml_fh['tags.mlflow.runName'] == 'RegistroModelo'].copy()
df_ml_fh_rg
# Out:
#                                run_id experiment_id    status  \
# 2    f48d0ab0640b4e63a53603561c546202             1  FINISHED
# 3    f580b9e531d8488392484e6e130262b6             1  FINISHED
# 4    266abda895364ba3b43cfa6c91a7b71b             1  FINISHED
# 5    4ea6dee8a2874efe87422664c8483316             1  FINISHED
# 75   9ccff4a2174c4e88a84ac90abfcf04b0             1  FINISHED
# 138  8a838d5cb1554d9a85e7c612e35e5c59             1  FINISHED
# 139  5b7c66141424424ea36ce09bb8ff4899             1  FINISHED
#
#                                           artifact_uri  \
# 2    ./mlruns/1/f48d0ab0640b4e63a53603561c546202/ar...
# 3    ./mlruns/1/f580b9e531d8488392484e6e130262b6/ar...
# 4    ./mlruns/1/266abda895364ba3b43cfa6c91a7b71b/ar...
# 5    ./mlruns/1/4ea6dee8a2874efe87422664c8483316/ar...
# 75   ./mlruns/1/9ccff4a2174c4e88a84ac90abfcf04b0/ar...
# 138  ./mlruns/1/8a838d5cb1554d9a85e7c612e35e5c59/ar...
# 139  ./mlruns/1/5b7c66141424424ea36ce09bb8ff4899/ar...
#
#                           start_time                         end_time  \
# 2   2022-04-17 21:44:08.578000+00:00 2022-04-17 21:44:12.444000+00:00
# 3   2022-04-17 21:43:15.710000+00:00 2022-04-17 21:43:19.609000+00:00
# 4   2022-04-17 21:40:10.859000+00:00 2022-04-17 21:40:14.749000+00:00
# 5   2022-04-17 21:27:07.500000+00:00 2022-04-17 21:27:11.621000+00:00
# 75  2022-04-17 19:42:21.552000+00:00 2022-04-17 19:42:25.441000+00:00
# 138 2022-04-17 18:52:48.295000+00:00 2022-04-17 18:52:51.953000+00:00
# 139 2022-04-17 18:51:43.835000+00:00 2022-04-17 18:51:47.397000+00:00
#
#      metrics.MCC  metrics.Recall  metrics.Accuracy  metrics.AUC  ...  \
# 2       0.170774        0.370224          0.590881     0.577473  ...
# 3       0.170774        0.370224          0.590881     0.577473  ...
# 4       0.170774        0.370224          0.590881     0.577473  ...
# 5       0.170774        0.370224          0.590881     0.577473  ...
# 75           NaN             NaN               NaN          NaN  ...
# 138          NaN             NaN               NaN          NaN  ...
# 139          NaN             NaN               NaN          NaN  ...
#
#      tags.mlflow.runName                      tags.mlflow.log-model.history  \
# 2         RegistroModelo  [{"run_id": "f48d0ab0640b4e63a53603561c546202"...
# 3         RegistroModelo  [{"run_id": "f580b9e531d8488392484e6e130262b6"...
# 4         RegistroModelo  [{"run_id": "266abda895364ba3b43cfa6c91a7b71b"...
# 5         RegistroModelo  [{"run_id": "4ea6dee8a2874efe87422664c8483316"...
# 75        RegistroModelo  [{"run_id": "9ccff4a2174c4e88a84ac90abfcf04b0"...
# 138       RegistroModelo  [{"run_id": "8a838d5cb1554d9a85e7c612e35e5c59"...
# 139       RegistroModelo  [{"run_id": "5b7c66141424424ea36ce09bb8ff4899"...
#
#      tags.Run Time  tags.USI  tags.URI  tags.Run ID  tags.Source  \
# 2             None      None      None         None         None
# 3             None      None      None         None         None
# 4             None      None      None         None         None
# 5             None      None      None         None         None
# 75            None      None      None         None         None
# 138           None      None      None         None         None
# 139           None      None      None         None         None
#
#      tags.mlflow.autologging  tags.estimator_name  tags.estimator_class
# 2                       None                 None                  None
# 3                       None                 None                  None
# 4                       None                 None                  None
# 5                       None                 None                  None
# 75                      None                 None                  None
# 138                     None                 None                  None
# 139                     None                 None                  None
#
# [7 rows x 308 columns]

# %%
df_ml_fh_rg.keys()
# Out:
# Index(['run_id', 'experiment_id', 'status', 'artifact_uri', 'start_time',
#        'end_time', 'metrics.MCC', 'metrics.Recall', 'metrics.Accuracy',
#        'metrics.AUC',
#        ...
#        'tags.mlflow.runName', 'tags.mlflow.log-model.history', 'tags.Run Time',
#        'tags.USI', 'tags.URI', 'tags.Run ID', 'tags.Source',
#        'tags.mlflow.autologging', 'tags.estimator_name',
#        'tags.estimator_class'],
#       dtype='object', length=308)

# %%
metrics_select = ['tags.mlflow.runName','metrics.LogLoss', 'metrics.F1','metrics.Accuracy', 'metrics.Prec.', 'metrics.Recall']

# %%
df_ml_fh_rg= df_ml_fh_rg[df_ml_fh_rg['metrics.LogLoss'].notnull()].reset_index()
df_ml_fh_rg= df_ml_fh_rg[df_ml_fh_rg['metrics.Version'].notnull()].reset_index()
df_ml_fh_rg
# Out:
#    level_0  index                            run_id experiment_id    status  \
# 0        0      2  f48d0ab0640b4e63a53603561c546202             1  FINISHED
# 1        1      3  f580b9e531d8488392484e6e130262b6             1  FINISHED
#
#                                         artifact_uri  \
# 0  ./mlruns/1/f48d0ab0640b4e63a53603561c546202/ar...
# 1  ./mlruns/1/f580b9e531d8488392484e6e130262b6/ar...
#
#                         start_time                         end_time  \
# 0 2022-04-17 21:44:08.578000+00:00 2022-04-17 21:44:12.444000+00:00
# 1 2022-04-17 21:43:15.710000+00:00 2022-04-17 21:43:19.609000+00:00
#
#    metrics.MCC  metrics.Recall  ...  tags.mlflow.runName  \
# 0     0.170774        0.370224  ...       RegistroModelo
# 1     0.170774        0.370224  ...       RegistroModelo
#
#                        tags.mlflow.log-model.history  tags.Run Time  tags.USI  \
# 0  [{"run_id": "f48d0ab0640b4e63a53603561c546202"...           None      None
# 1  [{"run_id": "f580b9e531d8488392484e6e130262b6"...           None      None
#
#    tags.URI  tags.Run ID  tags.Source  tags.mlflow.autologging  \
# 0      None         None         None                     None
# 1      None         None         None                     None
#
#    tags.estimator_name  tags.estimator_class
# 0                 None                  None
# 1                 None                  None
#
# [2 rows x 310 columns]

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.xlabel("N°")
plt.ylabel("Acurácia")

plt.plot(df_ml_fh_rg['metrics.Version'], df_ml_fh_rg['metrics.LogLoss'], 'o-', label="Log Loss", linewidth=4)
plt.legend() 
plt.show()

# %%
'parameters.Version' in df_ml_fh_rg.keys()
# Out:
# False

# %%
df_ml = mlflow.search_runs([experiment_id], order_by=["metrics.m DESC"])
df_ml_fh = df_ml[df_ml['status'] == 'FINISHED'].copy()
df_ml_fh_rv= df_ml_fh[df_ml_fh['tags.mlflow.runName'] == 'RevalidaçãoModelo'].copy()
df_ml_fh_rv = df_ml_fh_rv[df_ml_fh_rv['metrics.LogLoss'].notnull()].reset_index()
df_ml_fh_rv= df_ml_fh_rv[df_ml_fh_rv['metrics.Version'].notnull()].reset_index()
df_ml_fh_rv['metrics.Version'] = df_ml_fh_rg['metrics.Version']
#df_ml_fh_rv_i = pd.DataFrame({'metrics.Version': df_ml_fh_rg['metrics.Version']}, {} )
df_ml_fh_rv_i=df_ml_fh_rg['metrics.Version'].copy()
#{'col1': [1, 2], 'col2': [3, 4]}

# %%
df_ml_fh_rg['metrics.Version']
# Out:
# 0    8.0
# 1    7.0
# Name: metrics.Version, dtype: float64

# %%
type(df_ml_fh_rv_i)
# Out:
# pandas.core.series.Series
